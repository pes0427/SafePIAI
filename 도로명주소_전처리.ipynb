# %%
import os
import pandas as pd
from google.colab import drive

# 구글 드라이브 마운트
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 작업할 디렉토리 경로 설정 (드라이브 내의 경로로 변경)
directory_path = '/content/drive/MyDrive/road_address_hangul'  # 실제 디렉토리 경로로 변경해주세요

# %%
# 디렉토리 내의 모든 파일 목록 얻기
file_list = [file for file in os.listdir(directory_path) if file.endswith('.txt')]

# %%
print(file_list)
# Out:
# ['rnaddrkor_busan.txt', 'rnaddrkor_chungbuk.txt', 'rnaddrkor_chungnam.txt', 'rnaddrkor_daegu.txt', 'rnaddrkor_daejeon.txt', 'rnaddrkor_gwangju.txt', 'rnaddrkor_gangwon.txt', 'rnaddrkor_gyeongbuk.txt', 'rnaddrkor_gyeongnam.txt', 'rnaddrkor_gyunggi.txt', 'rnaddrkor_jeju.txt', 'rnaddrkor_incheon.txt', 'rnaddrkor_jeonbuk.txt', 'rnaddrkor_sejong.txt', 'rnaddrkor_jeonnam.txt', 'rnaddrkor_ulsan.txt', 'rnaddrkor_seoul.txt']

# %%
# 모든 파일에 대해 작업 수행하며 고유한 값을 저장할 배열 초기화
unique_values = []

# %%
# 모든 파일에 대해 작업 수행
for file_name in file_list:
    file_path = os.path.join(directory_path, file_name)

    # 각 파일을 읽어서 데이터프레임 생성
    df = pd.read_csv(file_path, sep='|', encoding='cp949')
    df.columns = ['도로명주소_관리번호','법정동_코드','시도명','시군구명','읍면동명','리명','산여부','번지','호','도로명코드','도로명','지하여부',
              '건물본번','건물부번','행정동코드','행정동명','기초구역번호','이전도로명주소','효력발생일','공동주택구분',
              '이동사유코드','건축물대장건물명','시군구용건물명','비고']

    # '도로명' 열의 고유한 값을 추가
    unique_values.extend(df['도로명'].unique())

# 모든 파일을 처리한 후에 고유한 값을 가진 데이터프레임 생성
unique_df = pd.DataFrame(unique_values, columns=['Road_Address'])

# 결과 CSV 파일을 구글 드라이브 내의 폴더에 저장 (드라이브 내의 경로로 변경)
output_file_path = os.path.join('/content/drive/MyDrive/Total_Road_Address', f'Total_Road_Address_Hangul.csv')
unique_df.to_csv(output_file_path, index=False, encoding='utf-8')
# Out:
# <ipython-input-16-ca5648b7bcf7>:6: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep='|', encoding='cp949')
# <ipython-input-16-ca5648b7bcf7>:6: DtypeWarning: Columns (5,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep='|', encoding='cp949')
# <ipython-input-16-ca5648b7bcf7>:6: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep='|', encoding='cp949')
# <ipython-input-16-ca5648b7bcf7>:6: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep='|', encoding='cp949')
# <ipython-input-16-ca5648b7bcf7>:6: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep='|', encoding='cp949')
# ...
